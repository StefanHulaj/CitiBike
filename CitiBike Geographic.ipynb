# %%
import pandas as pd
import os
from keplergl import KeplerGl 
from pyproj import CRS
import numpy as np
from matplotlib import pyplot as plt
# Out:
# C:\Users\stefa\anaconda3\envs\CitiBike\Lib\site-packages\keplergl\keplergl.py:2: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_string

# %%
path = r"C:\Users\stefa\CitiBike"

# %%
df = pd.read_csv(os.path.join(path, 'Prepared Data', 'CitiBikeWeatherWrangled.csv'),  index_col = False)

# %% [markdown]
# Step 3: In the data set from the previous task, create a new column with the value of 1. Then create a new aggregated dataframe that contains 3 columns: starting station, ending station, and the count of trips between those stations.

# %%
df.columns
# Out:
# Index(['date', 'ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'average_tempurature', 'bike_rides_daily', '_merge'],
#       dtype='object')

# %%
df = df.dropna()

# %%
df['value'] = 1
df_group = df.groupby(['start_station_name', 'end_station_name'])['value'].count().reset_index()

# %%
df_group
# Out:
#          start_station_name                   end_station_name  value
# 0     11 St & Washington St              11 St & Washington St   1132
# 1     11 St & Washington St                   12 Ave & W 40 St      1
# 2     11 St & Washington St               12 St & Sinatra Dr N    253
# 3     11 St & Washington St  14 St Ferry - 14 St & Shipyard Ln    395
# 4     11 St & Washington St                    4 St & Grand St    350
# ...                     ...                                ...    ...
# 6948   York St & Marin Blvd                     Van Vorst Park     18
# 6949   York St & Marin Blvd                          Warren St     42
# 6950   York St & Marin Blvd                      Washington St     16
# 6951   York St & Marin Blvd                 Willow Ave & 12 St      1
# 6952   York St & Marin Blvd               York St & Marin Blvd     47
#
# [6953 rows x 3 columns]

# %%
print(df_group['value'].sum())
print(df.shape)
# Out:
# 892281
# (892281, 18)

# %%
df_group.rename(columns = {'value': 'trips'}, inplace = True)

# %%
df_group
# Out:
#          start_station_name                   end_station_name  trips
# 0     11 St & Washington St              11 St & Washington St   1132
# 1     11 St & Washington St                   12 Ave & W 40 St      1
# 2     11 St & Washington St               12 St & Sinatra Dr N    253
# 3     11 St & Washington St  14 St Ferry - 14 St & Shipyard Ln    395
# 4     11 St & Washington St                    4 St & Grand St    350
# ...                     ...                                ...    ...
# 6948   York St & Marin Blvd                     Van Vorst Park     18
# 6949   York St & Marin Blvd                          Warren St     42
# 6950   York St & Marin Blvd                      Washington St     16
# 6951   York St & Marin Blvd                 Willow Ave & 12 St      1
# 6952   York St & Marin Blvd               York St & Marin Blvd     47
#
# [6953 rows x 3 columns]

# %% [markdown]
# Step 4: Initialize an instance of a kepler.gl map.

# %%
df_stations = df[['start_station_name', 'end_station_name', 'start_lat', 'start_lng', 'end_lat', 'end_lng']]

# %%
df_stations
# Out:
#                       start_station_name       end_station_name  start_lat  \
# 0                           Newport PATH           Newport PATH  40.727224
# 1                             Bergen Ave          Washington St  40.722104
# 2                                Sip Ave             Bergen Ave  40.730897
# 3                           Newport Pkwy           Jersey & 3rd  40.728745
# 4             Columbus Dr at Exchange Pl           Jersey & 3rd  40.716870
# ...                                  ...                    ...        ...
# 895480           Bergen Ave & Stegman St         Pershing Field  40.706717
# 895481  City Hall - Washington St & 1 St  11 St & Washington St  40.737360
# 895482     9 St HBLR - Jackson St & 8 St   12 St & Sinatra Dr N  40.747907
# 895483                     Grove St PATH            Dixon Mills  40.719410
# 895484              8 St & Washington St         Van Vorst Park  40.745928
#
#         start_lng    end_lat    end_lng
# 0      -74.033759  40.727224 -74.033759
# 1      -74.071455  40.724294 -74.035483
# 2      -74.063913  40.722104 -74.071455
# 3      -74.032108  40.723332 -74.045953
# 4      -74.032810  40.723332 -74.045953
# ...           ...        ...        ...
# 895480 -74.086701  40.742677 -74.051789
# 895481 -74.030970  40.749985 -74.027150
# 895482 -74.038412  40.750604 -74.024020
# 895483 -74.043090  40.721630 -74.049968
# 895484 -74.028123  40.718489 -74.047727
#
# [892281 rows x 6 columns]

# %% [markdown]
# df_m = df_group.merge(df_stations, how = 'outer', on = "start_station_name", indicator = 'merge_flag')

# %%
df_m = pd.merge(df_group, df_stations, on=['start_station_name', 'end_station_name'], how='outer', indicator = 'merge_flag')

# %%
df_m['merge_flag'].value_counts(dropna = True)
# Out:
# merge_flag
# both          892281
# left_only          0
# right_only         0
# Name: count, dtype: int64

# %%
df_m.shape
# Out:
# (892281, 8)

# %%
df_m.head()
# Out:
#       start_station_name       end_station_name  trips  start_lat  start_lng  \
# 0  11 St & Washington St  11 St & Washington St   1132  40.749985  -74.02715
# 1  11 St & Washington St  11 St & Washington St   1132  40.749985  -74.02715
# 2  11 St & Washington St  11 St & Washington St   1132  40.749985  -74.02715
# 3  11 St & Washington St  11 St & Washington St   1132  40.749985  -74.02715
# 4  11 St & Washington St  11 St & Washington St   1132  40.749985  -74.02715
#
#      end_lat   end_lng merge_flag
# 0  40.749985 -74.02715       both
# 1  40.749985 -74.02715       both
# 2  40.749985 -74.02715       both
# 3  40.749985 -74.02715       both
# 4  40.749985 -74.02715       both

# %%
df_m.drop(columns = ['merge_flag'])
# Out:
#            start_station_name       end_station_name  trips  start_lat  \
# 0       11 St & Washington St  11 St & Washington St   1132  40.749985
# 1       11 St & Washington St  11 St & Washington St   1132  40.749985
# 2       11 St & Washington St  11 St & Washington St   1132  40.749985
# 3       11 St & Washington St  11 St & Washington St   1132  40.749985
# 4       11 St & Washington St  11 St & Washington St   1132  40.749985
# ...                       ...                    ...    ...        ...
# 892276   York St & Marin Blvd   York St & Marin Blvd     47  40.716615
# 892277   York St & Marin Blvd   York St & Marin Blvd     47  40.716615
# 892278   York St & Marin Blvd   York St & Marin Blvd     47  40.716615
# 892279   York St & Marin Blvd   York St & Marin Blvd     47  40.716615
# 892280   York St & Marin Blvd   York St & Marin Blvd     47  40.716615
#
#         start_lng    end_lat    end_lng
# 0      -74.027150  40.749985 -74.027150
# 1      -74.027150  40.749985 -74.027150
# 2      -74.027150  40.749985 -74.027150
# 3      -74.027150  40.749985 -74.027150
# 4      -74.027150  40.749985 -74.027150
# ...           ...        ...        ...
# 892276 -74.042412  40.716615 -74.042412
# 892277 -74.042412  40.716615 -74.042412
# 892278 -74.042412  40.716615 -74.042412
# 892279 -74.042412  40.716615 -74.042412
# 892280 -74.042412  40.716615 -74.042412
#
# [892281 rows x 7 columns]

# %%
import gc # this is garbage collector - speeds up performance
gc.collect()
# Out:
# 209

# %%
indices_to_drop = df_m[df_m['trips'] < 100].index

# %%
df_m = df_m.drop(indices_to_drop)

# %%
df_m = df_m.reset_index(drop=True)

# %%
df_m
# Out:
#            start_station_name       end_station_name  trips  start_lat  \
# 0       11 St & Washington St  11 St & Washington St   1132  40.749985
# 1       11 St & Washington St  11 St & Washington St   1132  40.749985
# 2       11 St & Washington St  11 St & Washington St   1132  40.749985
# 3       11 St & Washington St  11 St & Washington St   1132  40.749985
# 4       11 St & Washington St  11 St & Washington St   1132  40.749985
# ...                       ...                    ...    ...        ...
# 772611     Willow Ave & 12 St     Willow Ave & 12 St    494  40.751867
# 772612     Willow Ave & 12 St     Willow Ave & 12 St    494  40.751867
# 772613     Willow Ave & 12 St     Willow Ave & 12 St    494  40.751975
# 772614     Willow Ave & 12 St     Willow Ave & 12 St    494  40.751867
# 772615     Willow Ave & 12 St     Willow Ave & 12 St    494  40.751867
#
#         start_lng    end_lat    end_lng merge_flag
# 0      -74.027150  40.749985 -74.027150       both
# 1      -74.027150  40.749985 -74.027150       both
# 2      -74.027150  40.749985 -74.027150       both
# 3      -74.027150  40.749985 -74.027150       both
# 4      -74.027150  40.749985 -74.027150       both
# ...           ...        ...        ...        ...
# 772611 -74.030377  40.751867 -74.030377       both
# 772612 -74.030377  40.751867 -74.030377       both
# 772613 -74.030357  40.751867 -74.030377       both
# 772614 -74.030377  40.751867 -74.030377       both
# 772615 -74.030377  40.751867 -74.030377       both
#
# [772616 rows x 8 columns]

# %%
df_m.to_csv(os.path.join(path, 'Prepared Data', 'CitiBike_final_locations_for_map_filtered.csv'))
