# %%
import os
import pandas as pd

# %%
path = r"C:\Users\stefa\CitiBike"

# %%
df = pd.read_csv(os.path.join(path, 'Prepared Data', 'CitiBikeWeatherWrangled.csv'),  index_col = False)

# %%
df['value'] = 1 
df_groupby_bar = df.groupby('start_station_name', as_index=False).agg({'value': 'sum'})
top20 = df_groupby_bar.nlargest(20, 'value')

# %%
top20.to_csv(os.path.join(path, 'Top20.csv'))

# %%
df
# Out:
#               date           ride_id rideable_type           started_at  \
# 0       2022-01-01  09517A19F52C8FE4  classic_bike  2022-01-01 14:51:51
# 1       2022-01-01  C7B485FB3EEC674C  classic_bike  2022-01-01 15:12:06
# 2       2022-01-01  A68C233443AF7685  classic_bike  2022-01-01 20:16:22
# 3       2022-01-01  F68B9199E986F2CA  classic_bike  2022-01-01 18:57:13
# 4       2022-01-01  F599BA9B9A1161ED  classic_bike  2022-01-01 00:24:59
# ...            ...               ...           ...                  ...
# 895480  2022-12-31  E15E8C86E750FFC9  classic_bike  2022-12-31 13:09:55
# 895481  2022-12-31  90E6D2FBD15566F4  classic_bike  2022-12-31 10:59:20
# 895482  2022-12-31  E7B1948B2FEEFC0C  classic_bike  2022-12-31 10:23:10
# 895483  2022-12-31  EB091A5358CE2ECE  classic_bike  2022-12-31 10:25:42
# 895484  2022-12-31  FA8BBCE78CDE9AEB  classic_bike  2022-12-31 00:11:22
#
#                    ended_at                start_station_name  \
# ...

# %%
df_weather = df[['date', 'average_tempurature', 'bike_rides_daily']].drop_duplicates()

# %%
df_weather
# Out:
#               date  average_tempurature  bike_rides_daily
# 0       2022-01-01                 11.6               592
# 592     2022-01-02                 11.4              1248
# 1840    2022-01-03                  1.4               832
# 2672    2022-01-04                 -2.7               934
# 3606    2022-01-05                  3.2               914
# ...            ...                  ...               ...
# 888524  2022-12-27                 -0.7              1049
# 889573  2022-12-28                  3.4              1399
# 890972  2022-12-29                  6.4              1601
# 892573  2022-12-30                  9.3              1929
# 894502  2022-12-31                  8.2               983
#
# [365 rows x 3 columns]

# %%
df_weather.to_csv(os.path.join(path, 'df_weather.csv'))
