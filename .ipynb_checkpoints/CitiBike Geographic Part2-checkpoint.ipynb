# %%
import pandas as pd
import os
from keplergl import KeplerGl 
from pyproj import CRS
import numpy as np
from matplotlib import pyplot as plt
# Out:
# C:\Users\stefa\anaconda3\envs\CitiBike\Lib\site-packages\keplergl\keplergl.py:2: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_string

# %%
path = r"C:\Users\stefa\CitiBike"

# %%
df = pd.read_csv(os.path.join(path, 'Prepared Data', 'CitiBike_final_locations_for_map_filtered.csv'),  index_col = False)

# %%
# Create KeplerGl instance

m = KeplerGl(height = 700, data={"data_1": df})
m
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# C:\Users\stefa\anaconda3\envs\CitiBike\Lib\site-packages\IPython\core\formatters.py:429: FormatterWarning: text/html formatter returned invalid type <class 'bytes'> (expected <class 'str'>) for object: KeplerGl(data={'data_1':         Unnamed: 0     start_station_name       end_station_name  trips  \
# 0                0  11 St & Washington St  11 St & Washington St   1132
# 1                1  11 St & Washington St  11 St & Washington St   1132
# 2                2  11 St & Washington St  11 St & Washington St   1132
# 3                3  11 St & Washington St  11 St & Washington St   1132
# 4                4  11 St & Washington St  11 St & Washington St   1132
# ...            ...                    ...                    ...    ...
# 892276      892276   York St & Marin Blvd   York St & Marin Blvd     47
# 892277      892277   York St & Marin Blvd   York St & Marin Blvd     47
# 892278      892278   York St & Marin Blvd   York St & Marin Blvd     47
# 892279      892279   York St & Marin Blvd   York St & Marin Blvd     47
# 892280      892280   York St & Marin Blvd   York St & Marin Blvd     47
#
#         start_lat  start_lng    end_lat    end_lng merge_flag
# 0       40.749985 -74.027150  40.749985 -74.027150       both
# 1       40.749985 -74.027150  40.749985 -74.027150       both
# 2       40.749985 -74.027150  40.749985 -74.027150       both
# 3       40.749985 -74.027150  40.749985 -74.027150       both
# 4       40.749985 -74.027150  40.749985 -74.027150       both
# ...           ...        ...        ...        ...        ...
# 892276  40.716615 -74.042412  40.716615 -74.042412       both
# 892277  40.716615 -74.042412  40.716615 -74.042412       both
# 892278  40.716615 -74.042412  40.716615 -74.042412       both
# 892279  40.716615 -74.042412  40.716615 -74.042412       both
# 892280  40.716615 -74.042412  40.716615 -74.042412       both
#
# [892281 rows x 9 columns]}, height=700)
#   warnings.warn(
# KeplerGl(data={'data_1':         Unnamed: 0     start_station_name       end_station_name  trips  \
# 0         …
